# %% [markdown]
# #uv add    torch

# %%
print("yolo")
# Out:
# yolo

# %%
import torch

# %%
tensor0d = torch.tensor(1)
tensor1d = torch.tensor([1, 2, 3])
tensor2d = torch.tensor([[1, 2], 
                          [3, 4]])
tensor3d = torch.tensor([[[1, 2],[3, 4]],
                          [[5, 6], [7, 8]]])

# %%
print(tensor0d)
print(tensor1d.dtype)
print(tensor2d)
print(tensor3d)
# Out:
# tensor(1)
# torch.int64
# tensor([[1, 2],
#         [3, 4]])
# tensor([[[1, 2],
#          [3, 4]],
#
#         [[5, 6],
#          [7, 8]]])

# %%
floatvec = torch.tensor([1.0, 2.0, 3.0])
print(floatvec.dtype)
# Out:
# torch.float32

# %%
print(tensor1d.dtype)
print(tensor1d)
floatvec = tensor1d.to(torch.float32)
print(floatvec.dtype)
print(floatvec)
# Out:
# torch.int64
# tensor([1, 2, 3])
# torch.float32
# tensor([1., 2., 3.])

# %%
tensor2d = torch.tensor([[1, 2, 3], 
                          [4, 5, 6]])
print(tensor2d)
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
print(tensor2d.shape)
# Out:
# torch.Size([2, 3])

# %%
print(tensor2d.reshape(3,2))
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])

# %%
print(tensor2d)
print(tensor2d.T)
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])
# tensor([[1, 4],
#         [2, 5],
#         [3, 6]])

# %%
print(tensor2d.matmul(tensor2d.T))
# Out:
# tensor([[14, 32],
#         [32, 77]])

# %%
tensoreasy = torch.tensor([[1,2],[3,4]])

# %%
tensoreasy = torch.tensor([[1,2],[3,4]])
tensoreasy2 = torch.tensor([[5,6],[7,8]])

print(tensoreasy)
print(tensoreasy.T)

print(tensoreasy.matmul(tensoreasy2))
# Out:
# tensor([[1, 2],
#         [3, 4]])
# tensor([[1, 3],
#         [2, 4]])
# tensor([[19, 22],
#         [43, 50]])
